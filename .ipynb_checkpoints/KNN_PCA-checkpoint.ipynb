# %%
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import pickle
import warnings

from sklearn.utils import shuffle
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsClassifier
from sklearn.linear_model import LogisticRegression

from sklearn.metrics import accuracy_score, f1_score, precision_score, recall_score, make_scorer
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay

from sklearn.model_selection import GridSearchCV

from sklearn.decomposition import PCA

warnings.filterwarnings('ignore')

SAVE_MODELS = False

# %% [markdown]
# # Load Data

# %%
data_train_1 = pickle.load(open("data/data_train_flatten_batch_1.pkl", "rb"))
data_train_2 = pickle.load(open("data/data_train_flatten_batch_2.pkl", "rb"))
labels_train_1 = pickle.load(open("data/labels_train_batch_1.pkl", "rb"))
labels_train_2 = pickle.load(open("data/labels_train_batch_2.pkl", "rb"))

data_train = np.concatenate((data_train_1, data_train_2))
labels_train = np.concatenate((labels_train_1, labels_train_2))

data_test = pickle.load(open("data/data_test_flatten.pkl", "rb"))
labels_test = pickle.load(open("data/labels_test.pkl", "rb"))

# Shuffle train set
data_train, labels_train = shuffle(data_train, labels_train, random_state=25)

# %% [markdown]
# # Scale Data

# %%
scaler = StandardScaler()

X_train_std = scaler.fit_transform(data_train)
X_test_std = scaler.transform(data_test)

# %% [markdown]
# # PCA
# We will use a 95% PCA

# %%
print("original number of features:", X_train_std.shape[1])
pca = PCA(0.95)
pca.fit(X_train_std)
print("Number of pricipal components:", pca.n_components_)

X_train_pca = pca.transform(X_train_std)
X_test_pca = pca.transform(X_test_std)
# Out:
# original number of features: 3072
# Number of pricipal components: 221

# %% [markdown]
# # Train Model

# %%
# Create custom scorer for tuning
def f1_global(y_true, y_pred):
    precision_macro = precision_score(y_true, y_pred, average="macro")
    recall_macro = recall_score(y_true, y_pred, average="macro")
    return (2 * precision_macro * recall_macro) / (precision_macro + recall_macro)

f1_global_scorer = make_scorer(f1_global, greater_is_better=True)


m = KNeighborsClassifier(n_jobs=-1)

parameters = [{
    "n_neighbors": range(3, 25),
    "weights": ["uniform", "distance"]
}]

grid_search = GridSearchCV(m, parameters, verbose=3, scoring=f1_global_scorer)
grid_search.fit(X_train_pca, labels_train)
model = grid_search.best_estimator_
# Out:
# Fitting 5 folds for each of 44 candidates, totalling 220 fits
# [CV 1/5] END ....n_neighbors=3, weights=uniform;, score=0.385 total time=  14.2s
# [CV 2/5] END ....n_neighbors=3, weights=uniform;, score=0.385 total time=  14.0s
# [CV 3/5] END ....n_neighbors=3, weights=uniform;, score=0.389 total time=  16.7s
# [CV 4/5] END ....n_neighbors=3, weights=uniform;, score=0.374 total time=  14.5s
# [CV 5/5] END ....n_neighbors=3, weights=uniform;, score=0.392 total time=  14.5s
# [CV 1/5] END ...n_neighbors=3, weights=distance;, score=0.385 total time=  14.0s
# [CV 2/5] END ...n_neighbors=3, weights=distance;, score=0.387 total time=  14.3s
# [CV 3/5] END ...n_neighbors=3, weights=distance;, score=0.400 total time=  14.4s
# [CV 4/5] END ...n_neighbors=3, weights=distance;, score=0.383 total time=  14.4s
# [CV 5/5] END ...n_neighbors=3, weights=distance;, score=0.405 total time=  14.1s
# [CV 1/5] END ....n_neighbors=4, weights=uniform;, score=0.384 total time=  15.7s
# [CV 2/5] END ....n_neighbors=4, weights=uniform;, score=0.389 total time=  15.9s
# [CV 3/5] END ....n_neighbors=4, weights=uniform;, score=0.393 total time=  15.6s
# [CV 4/5] END ....n_neighbors=4, weights=uniform;, score=0.376 total time=  15.1s
# [CV 5/5] END ....n_neighbors=4, weights=uniform;, score=0.391 total time=  16.0s
# [CV 1/5] END ...n_neighbors=4, weights=distance;, score=0.396 total time=  16.7s
# [CV 2/5] END ...n_neighbors=4, weights=distance;, score=0.396 total time=  16.2s
# [CV 3/5] END ...n_neighbors=4, weights=distance;, score=0.404 total time=  15.4s
# [CV 4/5] END ...n_neighbors=4, weights=distance;, score=0.388 total time=  15.5s
# [CV 5/5] END ...n_neighbors=4, weights=distance;, score=0.413 total time=  15.8s
# [CV 1/5] END ....n_neighbors=5, weights=uniform;, score=0.385 total time=  15.9s
# [CV 2/5] END ....n_neighbors=5, weights=uniform;, score=0.395 total time=  14.7s
# [CV 3/5] END ....n_neighbors=5, weights=uniform;, score=0.392 total time=  15.1s
# [CV 4/5] END ....n_neighbors=5, weights=uniform;, score=0.377 total time=  14.0s
# [CV 5/5] END ....n_neighbors=5, weights=uniform;, score=0.394 total time=  15.5s
# [CV 1/5] END ...n_neighbors=5, weights=distance;, score=0.400 total time=  14.9s
# [CV 2/5] END ...n_neighbors=5, weights=distance;, score=0.403 total time=  15.9s
# [CV 3/5] END ...n_neighbors=5, weights=distance;, score=0.406 total time=  15.7s
# [CV 4/5] END ...n_neighbors=5, weights=distance;, score=0.390 total time=  14.9s
# [CV 5/5] END ...n_neighbors=5, weights=distance;, score=0.416 total time=  15.0s
# [CV 1/5] END ....n_neighbors=6, weights=uniform;, score=0.392 total time=  16.0s
# [CV 2/5] END ....n_neighbors=6, weights=uniform;, score=0.395 total time=  15.5s
# [CV 3/5] END ....n_neighbors=6, weights=uniform;, score=0.391 total time=  15.2s
# [CV 4/5] END ....n_neighbors=6, weights=uniform;, score=0.388 total time=  14.0s
# [CV 5/5] END ....n_neighbors=6, weights=uniform;, score=0.396 total time=  14.2s
# [CV 1/5] END ...n_neighbors=6, weights=distance;, score=0.407 total time=  15.8s
# [CV 2/5] END ...n_neighbors=6, weights=distance;, score=0.409 total time=  15.3s
# [CV 3/5] END ...n_neighbors=6, weights=distance;, score=0.404 total time=  14.9s
# [CV 4/5] END ...n_neighbors=6, weights=distance;, score=0.398 total time=  14.8s
# [CV 5/5] END ...n_neighbors=6, weights=distance;, score=0.416 total time=  15.3s
# [CV 1/5] END ....n_neighbors=7, weights=uniform;, score=0.391 total time=  15.7s
# [CV 2/5] END ....n_neighbors=7, weights=uniform;, score=0.397 total time=  15.2s
# [CV 3/5] END ....n_neighbors=7, weights=uniform;, score=0.395 total time=  15.6s
# [CV 4/5] END ....n_neighbors=7, weights=uniform;, score=0.385 total time=  15.7s
# [CV 5/5] END ....n_neighbors=7, weights=uniform;, score=0.400 total time=  16.1s
# [CV 1/5] END ...n_neighbors=7, weights=distance;, score=0.404 total time=  16.2s
# [CV 2/5] END ...n_neighbors=7, weights=distance;, score=0.409 total time=  15.8s
# [CV 3/5] END ...n_neighbors=7, weights=distance;, score=0.407 total time=  15.5s
# [CV 4/5] END ...n_neighbors=7, weights=distance;, score=0.399 total time=  15.2s
# [CV 5/5] END ...n_neighbors=7, weights=distance;, score=0.413 total time=  15.2s
# [CV 1/5] END ....n_neighbors=8, weights=uniform;, score=0.390 total time=  17.3s
# [CV 2/5] END ....n_neighbors=8, weights=uniform;, score=0.398 total time=  17.1s
# [CV 3/5] END ....n_neighbors=8, weights=uniform;, score=0.396 total time=  16.2s
# [CV 4/5] END ....n_neighbors=8, weights=uniform;, score=0.388 total time=  16.9s
# [CV 5/5] END ....n_neighbors=8, weights=uniform;, score=0.400 total time=  17.4s
# [CV 1/5] END ...n_neighbors=8, weights=distance;, score=0.403 total time=  17.3s
# [CV 2/5] END ...n_neighbors=8, weights=distance;, score=0.410 total time=  15.9s
# [CV 3/5] END ...n_neighbors=8, weights=distance;, score=0.408 total time=  15.7s
# [CV 4/5] END ...n_neighbors=8, weights=distance;, score=0.401 total time=  15.4s
# [CV 5/5] END ...n_neighbors=8, weights=distance;, score=0.412 total time=  18.5s
# [CV 1/5] END ....n_neighbors=9, weights=uniform;, score=0.390 total time=  17.3s
# [CV 2/5] END ....n_neighbors=9, weights=uniform;, score=0.402 total time=  16.8s
# [CV 3/5] END ....n_neighbors=9, weights=uniform;, score=0.394 total time=  15.5s
# [CV 4/5] END ....n_neighbors=9, weights=uniform;, score=0.386 total time=  14.7s
# [CV 5/5] END ....n_neighbors=9, weights=uniform;, score=0.401 total time=  15.1s
# [CV 1/5] END ...n_neighbors=9, weights=distance;, score=0.400 total time=  16.0s
# [CV 2/5] END ...n_neighbors=9, weights=distance;, score=0.411 total time=  15.8s
# [CV 3/5] END ...n_neighbors=9, weights=distance;, score=0.409 total time=  16.0s
# [CV 4/5] END ...n_neighbors=9, weights=distance;, score=0.399 total time=  15.7s
# [CV 5/5] END ...n_neighbors=9, weights=distance;, score=0.414 total time=  16.1s
# [CV 1/5] END ...n_neighbors=10, weights=uniform;, score=0.390 total time=  16.6s
# [CV 2/5] END ...n_neighbors=10, weights=uniform;, score=0.403 total time=  15.4s
# [CV 3/5] END ...n_neighbors=10, weights=uniform;, score=0.390 total time=  16.1s
# [CV 4/5] END ...n_neighbors=10, weights=uniform;, score=0.385 total time=  15.5s
# [CV 5/5] END ...n_neighbors=10, weights=uniform;, score=0.402 total time=  15.8s
# [CV 1/5] END ..n_neighbors=10, weights=distance;, score=0.400 total time=  16.3s
# [CV 2/5] END ..n_neighbors=10, weights=distance;, score=0.415 total time=  15.7s
# [CV 3/5] END ..n_neighbors=10, weights=distance;, score=0.403 total time=  15.8s
# [CV 4/5] END ..n_neighbors=10, weights=distance;, score=0.395 total time=  15.2s
# [CV 5/5] END ..n_neighbors=10, weights=distance;, score=0.412 total time=  15.2s
# [CV 1/5] END ...n_neighbors=11, weights=uniform;, score=0.388 total time=  16.6s
# [CV 2/5] END ...n_neighbors=11, weights=uniform;, score=0.404 total time=  15.7s
# [CV 3/5] END ...n_neighbors=11, weights=uniform;, score=0.394 total time=  15.3s
# [CV 4/5] END ...n_neighbors=11, weights=uniform;, score=0.385 total time=  15.2s
# [CV 5/5] END ...n_neighbors=11, weights=uniform;, score=0.399 total time=  14.8s
# [CV 1/5] END ..n_neighbors=11, weights=distance;, score=0.398 total time=  16.7s
# [CV 2/5] END ..n_neighbors=11, weights=distance;, score=0.414 total time=  16.3s
# [CV 3/5] END ..n_neighbors=11, weights=distance;, score=0.408 total time=  15.8s
# [CV 4/5] END ..n_neighbors=11, weights=distance;, score=0.397 total time=  15.4s
# [CV 5/5] END ..n_neighbors=11, weights=distance;, score=0.409 total time=  16.7s
# [CV 1/5] END ...n_neighbors=12, weights=uniform;, score=0.387 total time=  17.9s
# [CV 2/5] END ...n_neighbors=12, weights=uniform;, score=0.402 total time=  16.6s
# [CV 3/5] END ...n_neighbors=12, weights=uniform;, score=0.396 total time=  17.8s
# [CV 4/5] END ...n_neighbors=12, weights=uniform;, score=0.384 total time=  16.2s
# [CV 5/5] END ...n_neighbors=12, weights=uniform;, score=0.399 total time=  16.2s
# [CV 1/5] END ..n_neighbors=12, weights=distance;, score=0.400 total time=  16.9s
# [CV 2/5] END ..n_neighbors=12, weights=distance;, score=0.412 total time=  16.2s
# [CV 3/5] END ..n_neighbors=12, weights=distance;, score=0.407 total time=  16.5s
# [CV 4/5] END ..n_neighbors=12, weights=distance;, score=0.397 total time=  15.6s
# [CV 5/5] END ..n_neighbors=12, weights=distance;, score=0.409 total time=  15.9s
# [CV 1/5] END ...n_neighbors=13, weights=uniform;, score=0.388 total time=  17.5s
# [CV 2/5] END ...n_neighbors=13, weights=uniform;, score=0.401 total time=  17.1s
# [CV 3/5] END ...n_neighbors=13, weights=uniform;, score=0.395 total time=  16.5s
# [CV 4/5] END ...n_neighbors=13, weights=uniform;, score=0.385 total time=  16.1s
# [CV 5/5] END ...n_neighbors=13, weights=uniform;, score=0.399 total time=  16.4s
# [CV 1/5] END ..n_neighbors=13, weights=distance;, score=0.397 total time=  16.6s
# [CV 2/5] END ..n_neighbors=13, weights=distance;, score=0.410 total time=  16.1s
# [CV 3/5] END ..n_neighbors=13, weights=distance;, score=0.409 total time=  15.3s
# [CV 4/5] END ..n_neighbors=13, weights=distance;, score=0.396 total time=  15.8s
# [CV 5/5] END ..n_neighbors=13, weights=distance;, score=0.408 total time=  15.8s
# [CV 1/5] END ...n_neighbors=14, weights=uniform;, score=0.387 total time=  17.0s
# [CV 2/5] END ...n_neighbors=14, weights=uniform;, score=0.400 total time=  16.4s
# [CV 3/5] END ...n_neighbors=14, weights=uniform;, score=0.396 total time=  16.5s
# [CV 4/5] END ...n_neighbors=14, weights=uniform;, score=0.381 total time=  14.8s
# [CV 5/5] END ...n_neighbors=14, weights=uniform;, score=0.403 total time=  15.1s
# [CV 1/5] END ..n_neighbors=14, weights=distance;, score=0.396 total time=  16.2s
# [CV 2/5] END ..n_neighbors=14, weights=distance;, score=0.407 total time=  15.7s
# [CV 3/5] END ..n_neighbors=14, weights=distance;, score=0.405 total time=  14.7s
# [CV 4/5] END ..n_neighbors=14, weights=distance;, score=0.394 total time=  14.3s
# [CV 5/5] END ..n_neighbors=14, weights=distance;, score=0.410 total time=  15.7s
# [CV 1/5] END ...n_neighbors=15, weights=uniform;, score=0.385 total time=  15.7s
# [CV 2/5] END ...n_neighbors=15, weights=uniform;, score=0.402 total time=  15.0s
# [CV 3/5] END ...n_neighbors=15, weights=uniform;, score=0.394 total time=  14.8s
# [CV 4/5] END ...n_neighbors=15, weights=uniform;, score=0.383 total time=  15.8s
# [CV 5/5] END ...n_neighbors=15, weights=uniform;, score=0.401 total time=  16.3s
# [CV 1/5] END ..n_neighbors=15, weights=distance;, score=0.397 total time=  17.3s
# [CV 2/5] END ..n_neighbors=15, weights=distance;, score=0.410 total time=  16.0s
# [CV 3/5] END ..n_neighbors=15, weights=distance;, score=0.405 total time=  15.4s
# [CV 4/5] END ..n_neighbors=15, weights=distance;, score=0.395 total time=  15.1s
# [CV 5/5] END ..n_neighbors=15, weights=distance;, score=0.409 total time=  15.7s
# [CV 1/5] END ...n_neighbors=16, weights=uniform;, score=0.390 total time=  16.3s
# [CV 2/5] END ...n_neighbors=16, weights=uniform;, score=0.401 total time=  16.4s
# [CV 3/5] END ...n_neighbors=16, weights=uniform;, score=0.395 total time=  15.2s
# [CV 4/5] END ...n_neighbors=16, weights=uniform;, score=0.381 total time=  14.5s
# [CV 5/5] END ...n_neighbors=16, weights=uniform;, score=0.403 total time=  15.2s
# [CV 1/5] END ..n_neighbors=16, weights=distance;, score=0.397 total time=  15.3s
# [CV 2/5] END ..n_neighbors=16, weights=distance;, score=0.409 total time=  16.0s
# [CV 3/5] END ..n_neighbors=16, weights=distance;, score=0.403 total time=  15.4s
# [CV 4/5] END ..n_neighbors=16, weights=distance;, score=0.395 total time=  14.6s
# [CV 5/5] END ..n_neighbors=16, weights=distance;, score=0.410 total time=  16.2s
# [CV 1/5] END ...n_neighbors=17, weights=uniform;, score=0.389 total time=  16.1s
# [CV 2/5] END ...n_neighbors=17, weights=uniform;, score=0.399 total time=  15.2s
# [CV 3/5] END ...n_neighbors=17, weights=uniform;, score=0.399 total time=  14.9s
# [CV 4/5] END ...n_neighbors=17, weights=uniform;, score=0.381 total time=  15.3s
# [CV 5/5] END ...n_neighbors=17, weights=uniform;, score=0.401 total time=  15.2s
# [CV 1/5] END ..n_neighbors=17, weights=distance;, score=0.395 total time=  17.1s
# [CV 2/5] END ..n_neighbors=17, weights=distance;, score=0.408 total time=  16.1s
# [CV 3/5] END ..n_neighbors=17, weights=distance;, score=0.407 total time=  14.9s
# [CV 4/5] END ..n_neighbors=17, weights=distance;, score=0.391 total time=  14.4s
# [CV 5/5] END ..n_neighbors=17, weights=distance;, score=0.408 total time=  15.4s
# [CV 1/5] END ...n_neighbors=18, weights=uniform;, score=0.386 total time=  15.6s
# [CV 2/5] END ...n_neighbors=18, weights=uniform;, score=0.402 total time=  15.2s
# [CV 3/5] END ...n_neighbors=18, weights=uniform;, score=0.396 total time=  15.8s
# [CV 4/5] END ...n_neighbors=18, weights=uniform;, score=0.382 total time=  15.0s
# [CV 5/5] END ...n_neighbors=18, weights=uniform;, score=0.400 total time=  15.4s
# [CV 1/5] END ..n_neighbors=18, weights=distance;, score=0.394 total time=  17.3s
# [CV 2/5] END ..n_neighbors=18, weights=distance;, score=0.409 total time=  16.2s
# [CV 3/5] END ..n_neighbors=18, weights=distance;, score=0.406 total time=  16.1s
# [CV 4/5] END ..n_neighbors=18, weights=distance;, score=0.392 total time=  14.2s
# [CV 5/5] END ..n_neighbors=18, weights=distance;, score=0.407 total time=  15.9s
# [CV 1/5] END ...n_neighbors=19, weights=uniform;, score=0.384 total time=  17.2s
# [CV 2/5] END ...n_neighbors=19, weights=uniform;, score=0.403 total time=  15.6s
# [CV 3/5] END ...n_neighbors=19, weights=uniform;, score=0.398 total time=  15.4s
# [CV 4/5] END ...n_neighbors=19, weights=uniform;, score=0.383 total time=  14.3s
# [CV 5/5] END ...n_neighbors=19, weights=uniform;, score=0.398 total time=  14.2s
# [CV 1/5] END ..n_neighbors=19, weights=distance;, score=0.394 total time=  15.0s
# [CV 2/5] END ..n_neighbors=19, weights=distance;, score=0.410 total time=  14.5s
# [CV 3/5] END ..n_neighbors=19, weights=distance;, score=0.405 total time=  14.2s
# [CV 4/5] END ..n_neighbors=19, weights=distance;, score=0.391 total time=  14.1s
# [CV 5/5] END ..n_neighbors=19, weights=distance;, score=0.407 total time=  14.2s
# [CV 1/5] END ...n_neighbors=20, weights=uniform;, score=0.385 total time=  15.1s
# [CV 2/5] END ...n_neighbors=20, weights=uniform;, score=0.400 total time=  14.5s
# [CV 3/5] END ...n_neighbors=20, weights=uniform;, score=0.396 total time=  14.7s
# [CV 4/5] END ...n_neighbors=20, weights=uniform;, score=0.380 total time=  13.9s
# [CV 5/5] END ...n_neighbors=20, weights=uniform;, score=0.401 total time=  14.7s
# [CV 1/5] END ..n_neighbors=20, weights=distance;, score=0.392 total time=  15.0s
# [CV 2/5] END ..n_neighbors=20, weights=distance;, score=0.409 total time=  14.4s
# [CV 3/5] END ..n_neighbors=20, weights=distance;, score=0.406 total time=  15.5s
# [CV 4/5] END ..n_neighbors=20, weights=distance;, score=0.391 total time=  15.4s
# [CV 5/5] END ..n_neighbors=20, weights=distance;, score=0.409 total time=  15.7s
# [CV 1/5] END ...n_neighbors=21, weights=uniform;, score=0.387 total time=  17.8s
# [CV 2/5] END ...n_neighbors=21, weights=uniform;, score=0.401 total time=  16.7s
# [CV 3/5] END ...n_neighbors=21, weights=uniform;, score=0.394 total time=  16.7s
# [CV 4/5] END ...n_neighbors=21, weights=uniform;, score=0.381 total time=  14.8s
# [CV 5/5] END ...n_neighbors=21, weights=uniform;, score=0.399 total time=  15.4s
# [CV 1/5] END ..n_neighbors=21, weights=distance;, score=0.394 total time=  16.7s
# [CV 2/5] END ..n_neighbors=21, weights=distance;, score=0.408 total time=  16.5s
# [CV 3/5] END ..n_neighbors=21, weights=distance;, score=0.405 total time=  15.8s
# [CV 4/5] END ..n_neighbors=21, weights=distance;, score=0.390 total time=  16.1s
# [CV 5/5] END ..n_neighbors=21, weights=distance;, score=0.407 total time=  16.1s
# [CV 1/5] END ...n_neighbors=22, weights=uniform;, score=0.386 total time=  17.4s
# [CV 2/5] END ...n_neighbors=22, weights=uniform;, score=0.398 total time=  16.5s
# [CV 3/5] END ...n_neighbors=22, weights=uniform;, score=0.395 total time=  15.9s
# [CV 4/5] END ...n_neighbors=22, weights=uniform;, score=0.383 total time=  16.8s
# [CV 5/5] END ...n_neighbors=22, weights=uniform;, score=0.399 total time=  16.0s
# [CV 1/5] END ..n_neighbors=22, weights=distance;, score=0.396 total time=  16.9s
# [CV 2/5] END ..n_neighbors=22, weights=distance;, score=0.408 total time=  15.4s
# [CV 3/5] END ..n_neighbors=22, weights=distance;, score=0.406 total time=  15.7s
# [CV 4/5] END ..n_neighbors=22, weights=distance;, score=0.390 total time=  15.2s
# [CV 5/5] END ..n_neighbors=22, weights=distance;, score=0.406 total time=  14.9s
# [CV 1/5] END ...n_neighbors=23, weights=uniform;, score=0.385 total time=  15.5s
# [CV 2/5] END ...n_neighbors=23, weights=uniform;, score=0.398 total time=  15.2s
# [CV 3/5] END ...n_neighbors=23, weights=uniform;, score=0.396 total time=  15.4s
# [CV 4/5] END ...n_neighbors=23, weights=uniform;, score=0.381 total time=  15.7s
# [CV 5/5] END ...n_neighbors=23, weights=uniform;, score=0.393 total time=  15.5s
# [CV 1/5] END ..n_neighbors=23, weights=distance;, score=0.395 total time=  16.4s
# [CV 2/5] END ..n_neighbors=23, weights=distance;, score=0.405 total time=  15.8s
# [CV 3/5] END ..n_neighbors=23, weights=distance;, score=0.407 total time=  16.1s
# [CV 4/5] END ..n_neighbors=23, weights=distance;, score=0.387 total time=  15.6s
# [CV 5/5] END ..n_neighbors=23, weights=distance;, score=0.404 total time=  15.5s
# [CV 1/5] END ...n_neighbors=24, weights=uniform;, score=0.387 total time=  17.1s
# [CV 2/5] END ...n_neighbors=24, weights=uniform;, score=0.400 total time=  17.0s
# [CV 3/5] END ...n_neighbors=24, weights=uniform;, score=0.397 total time=  17.5s
# [CV 4/5] END ...n_neighbors=24, weights=uniform;, score=0.384 total time=  15.3s
# [CV 5/5] END ...n_neighbors=24, weights=uniform;, score=0.393 total time=  16.3s
# [CV 1/5] END ..n_neighbors=24, weights=distance;, score=0.397 total time=  16.2s
# [CV 2/5] END ..n_neighbors=24, weights=distance;, score=0.405 total time=  15.8s
# [CV 3/5] END ..n_neighbors=24, weights=distance;, score=0.405 total time=  16.3s
# [CV 4/5] END ..n_neighbors=24, weights=distance;, score=0.392 total time=  16.1s
# [CV 5/5] END ..n_neighbors=24, weights=distance;, score=0.403 total time=  15.1s

# %%
grid_search.best_score_
# Out:
# 0.40683432882433584

# %%
print("Model optimal parameters".upper())
print("n_neighbors:", model.get_params()["n_neighbors"])
print("weights:", model.get_params()["weights"])
# Out:
# MODEL OPTIMAL PARAMETERS
# n_neighbors: 6
# weights: distance

# %% [markdown]
# # Test Model

# %%
predictions = model.predict(X_test_pca)

accuracy = accuracy_score(labels_test, predictions)
precision = precision_score(labels_test, predictions, average="macro")
recall = recall_score(labels_test, predictions, average="macro")
f1_macro = f1_score(labels_test, predictions, average="macro")
f1_glob = (2 * precision * recall) / (precision + recall)

print("Accuracy score: {:.4f}%\nPrecision macro: {:.4f}%\nRecall macro: {:.4f}%".format(accuracy*100,precision*100,recall*100))
print("F1 macro: {:.4f}%\nF1 global: {:.4f}%".format(f1_macro*100, f1_glob*100))
# Out:
# Accuracy score: 38.1100%
# Precision macro: 45.8007%
# Recall macro: 38.1100%
#
# F1 macro: 37.4606%
# F1 global: 41.6029%

# %%
cm = confusion_matrix(labels_test, predictions, labels=model.classes_)
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=model.classes_)
disp.plot()
plt.show()

# %% [markdown]
# # Save Model

# %%
if SAVE_MODELS:
    model_file_name = "knn_pca.pkl"
    pickle.dump(model, open(model_file_name, "wb"))

# %% [markdown]
# # Black And White

# %% [markdown]
# ## Load data

# %%
train_batches = []
labels_batches = []

for i in [1, 2, 3, 4, 5]:
    data_filepath = "data/data_train_bw_flatten_batch_" + str(i) + ".pkl"
    labels_filepath = "data/labels_train_bw_batch_" + str(i) + ".pkl"
    train_batches.append(pickle.load(open(data_filepath, "rb")))
    labels_batches.append(pickle.load(open(labels_filepath, "rb")))
    
data_train_bw = np.concatenate(train_batches)
labels_train_bw = np.concatenate(labels_batches)

data_test_bw = pickle.load(open("data/data_test_bw_flatten.pkl", "rb"))
labels_test_bw = pickle.load(open("data/labels_test_bw.pkl", "rb"))

# Shuffle train set
data_train_bw, labels_train_bw = shuffle(data_train_bw, labels_train_bw, random_state=25)

# %% [markdown]
# ## Scale data

# %%
scaler = StandardScaler()

X_train_std_bw = scaler.fit_transform(data_train_bw)
X_test_std_bw = scaler.transform(data_test_bw)

# %% [markdown]
# ## PCA
# We will use a 95% PCA

# %%
del pca
print("original number of features:", X_train_std_bw.shape[1])
pca = PCA(0.95)
pca.fit(X_train_std_bw)
print("Number of pricipal components:", pca.n_components_)

X_train_bw_pca = pca.transform(X_train_std_bw)
X_test_bw_pca = pca.transform(X_test_std_bw)
# Out:
# original number of features: 1024
# Number of pricipal components: 163

# %% [markdown]
# ## Train model

# %%
m = KNeighborsClassifier(n_jobs=-1)

parameters = [{
    "n_neighbors": range(3, 25),
    "weights": ["uniform", "distance"]
}]

grid_search = GridSearchCV(m, parameters, verbose=3, scoring=f1_global_scorer)
grid_search.fit(X_train_bw_pca, labels_train_bw)
model_bw = grid_search.best_estimator_
print(grid_search.best_score_)
# Out:
# Fitting 5 folds for each of 44 candidates, totalling 220 fits
# [CV 1/5] END ....n_neighbors=3, weights=uniform;, score=0.334 total time=  13.8s
# [CV 2/5] END ....n_neighbors=3, weights=uniform;, score=0.336 total time=  13.4s
# [CV 3/5] END ....n_neighbors=3, weights=uniform;, score=0.345 total time=  13.6s
# [CV 4/5] END ....n_neighbors=3, weights=uniform;, score=0.329 total time=  13.6s
# [CV 5/5] END ....n_neighbors=3, weights=uniform;, score=0.349 total time=  13.1s
# [CV 1/5] END ...n_neighbors=3, weights=distance;, score=0.346 total time=  12.8s
# [CV 2/5] END ...n_neighbors=3, weights=distance;, score=0.344 total time=  13.4s
# [CV 3/5] END ...n_neighbors=3, weights=distance;, score=0.356 total time=  13.8s
# [CV 4/5] END ...n_neighbors=3, weights=distance;, score=0.336 total time=  13.9s
# [CV 5/5] END ...n_neighbors=3, weights=distance;, score=0.358 total time=  13.9s
# [CV 1/5] END ....n_neighbors=4, weights=uniform;, score=0.337 total time=  15.8s
# [CV 2/5] END ....n_neighbors=4, weights=uniform;, score=0.343 total time=  15.3s
# [CV 3/5] END ....n_neighbors=4, weights=uniform;, score=0.347 total time=  15.6s
# [CV 4/5] END ....n_neighbors=4, weights=uniform;, score=0.331 total time=  14.7s
# [CV 5/5] END ....n_neighbors=4, weights=uniform;, score=0.350 total time=  14.1s
# [CV 1/5] END ...n_neighbors=4, weights=distance;, score=0.350 total time=  15.5s
# [CV 2/5] END ...n_neighbors=4, weights=distance;, score=0.352 total time=  14.4s
# [CV 3/5] END ...n_neighbors=4, weights=distance;, score=0.360 total time=  14.6s
# [CV 4/5] END ...n_neighbors=4, weights=distance;, score=0.342 total time=  14.3s
# [CV 5/5] END ...n_neighbors=4, weights=distance;, score=0.368 total time=  13.9s
# [CV 1/5] END ....n_neighbors=5, weights=uniform;, score=0.336 total time=  14.9s
# [CV 2/5] END ....n_neighbors=5, weights=uniform;, score=0.348 total time=  14.7s
# [CV 3/5] END ....n_neighbors=5, weights=uniform;, score=0.351 total time=  14.6s
# [CV 4/5] END ....n_neighbors=5, weights=uniform;, score=0.333 total time=  13.9s
# [CV 5/5] END ....n_neighbors=5, weights=uniform;, score=0.354 total time=  14.1s
# [CV 1/5] END ...n_neighbors=5, weights=distance;, score=0.350 total time=  14.6s
# [CV 2/5] END ...n_neighbors=5, weights=distance;, score=0.356 total time=  14.4s
# [CV 3/5] END ...n_neighbors=5, weights=distance;, score=0.364 total time=  14.2s
# [CV 4/5] END ...n_neighbors=5, weights=distance;, score=0.349 total time=  13.8s
# [CV 5/5] END ...n_neighbors=5, weights=distance;, score=0.373 total time=  14.4s
# [CV 1/5] END ....n_neighbors=6, weights=uniform;, score=0.343 total time=  15.1s
# [CV 2/5] END ....n_neighbors=6, weights=uniform;, score=0.348 total time=  14.5s
# [CV 3/5] END ....n_neighbors=6, weights=uniform;, score=0.352 total time=  14.3s
# [CV 4/5] END ....n_neighbors=6, weights=uniform;, score=0.334 total time=  14.9s
# [CV 5/5] END ....n_neighbors=6, weights=uniform;, score=0.352 total time=  14.9s
# [CV 1/5] END ...n_neighbors=6, weights=distance;, score=0.354 total time=  15.6s
# [CV 2/5] END ...n_neighbors=6, weights=distance;, score=0.359 total time=  13.9s
# [CV 3/5] END ...n_neighbors=6, weights=distance;, score=0.362 total time=  14.0s
# [CV 4/5] END ...n_neighbors=6, weights=distance;, score=0.351 total time=  13.6s
# [CV 5/5] END ...n_neighbors=6, weights=distance;, score=0.371 total time=  13.9s
# [CV 1/5] END ....n_neighbors=7, weights=uniform;, score=0.348 total time=  14.6s
# [CV 2/5] END ....n_neighbors=7, weights=uniform;, score=0.350 total time=  14.2s
# [CV 3/5] END ....n_neighbors=7, weights=uniform;, score=0.354 total time=  14.7s
# [CV 4/5] END ....n_neighbors=7, weights=uniform;, score=0.339 total time=  13.4s
# [CV 5/5] END ....n_neighbors=7, weights=uniform;, score=0.355 total time=  13.3s
# [CV 1/5] END ...n_neighbors=7, weights=distance;, score=0.358 total time=  13.5s
# [CV 2/5] END ...n_neighbors=7, weights=distance;, score=0.360 total time=  13.5s
# [CV 3/5] END ...n_neighbors=7, weights=distance;, score=0.368 total time=  13.6s
# [CV 4/5] END ...n_neighbors=7, weights=distance;, score=0.353 total time=  13.2s
# [CV 5/5] END ...n_neighbors=7, weights=distance;, score=0.369 total time=  14.8s
# [CV 1/5] END ....n_neighbors=8, weights=uniform;, score=0.351 total time=  16.0s
# [CV 2/5] END ....n_neighbors=8, weights=uniform;, score=0.349 total time=  14.7s
# [CV 3/5] END ....n_neighbors=8, weights=uniform;, score=0.357 total time=  14.2s
# [CV 4/5] END ....n_neighbors=8, weights=uniform;, score=0.340 total time=  16.4s
# [CV 5/5] END ....n_neighbors=8, weights=uniform;, score=0.353 total time=  14.2s
# [CV 1/5] END ...n_neighbors=8, weights=distance;, score=0.361 total time=  14.5s
# [CV 2/5] END ...n_neighbors=8, weights=distance;, score=0.363 total time=  14.1s
# [CV 3/5] END ...n_neighbors=8, weights=distance;, score=0.368 total time=  14.4s
# [CV 4/5] END ...n_neighbors=8, weights=distance;, score=0.353 total time=  13.9s
# [CV 5/5] END ...n_neighbors=8, weights=distance;, score=0.367 total time=  13.8s
# [CV 1/5] END ....n_neighbors=9, weights=uniform;, score=0.351 total time=  14.8s
# [CV 2/5] END ....n_neighbors=9, weights=uniform;, score=0.355 total time=  14.1s
# [CV 3/5] END ....n_neighbors=9, weights=uniform;, score=0.352 total time=  14.5s
# [CV 4/5] END ....n_neighbors=9, weights=uniform;, score=0.344 total time=  13.9s
# [CV 5/5] END ....n_neighbors=9, weights=uniform;, score=0.352 total time=  13.9s
# [CV 1/5] END ...n_neighbors=9, weights=distance;, score=0.361 total time=  14.7s
# [CV 2/5] END ...n_neighbors=9, weights=distance;, score=0.365 total time=  14.6s
# [CV 3/5] END ...n_neighbors=9, weights=distance;, score=0.366 total time=  14.8s
# [CV 4/5] END ...n_neighbors=9, weights=distance;, score=0.358 total time=  14.4s
# [CV 5/5] END ...n_neighbors=9, weights=distance;, score=0.366 total time=  14.7s
# [CV 1/5] END ...n_neighbors=10, weights=uniform;, score=0.352 total time=  15.6s
# [CV 2/5] END ...n_neighbors=10, weights=uniform;, score=0.355 total time=  15.2s
# [CV 3/5] END ...n_neighbors=10, weights=uniform;, score=0.353 total time=  15.0s
# [CV 4/5] END ...n_neighbors=10, weights=uniform;, score=0.345 total time=  14.8s
# [CV 5/5] END ...n_neighbors=10, weights=uniform;, score=0.352 total time=  14.4s
# [CV 1/5] END ..n_neighbors=10, weights=distance;, score=0.362 total time=  14.9s
# [CV 2/5] END ..n_neighbors=10, weights=distance;, score=0.367 total time=  14.8s
# [CV 3/5] END ..n_neighbors=10, weights=distance;, score=0.364 total time=  14.7s
# [CV 4/5] END ..n_neighbors=10, weights=distance;, score=0.358 total time=  14.4s
# [CV 5/5] END ..n_neighbors=10, weights=distance;, score=0.369 total time=  14.4s
# [CV 1/5] END ...n_neighbors=11, weights=uniform;, score=0.352 total time=  15.2s
# [CV 2/5] END ...n_neighbors=11, weights=uniform;, score=0.354 total time=  14.6s
# [CV 3/5] END ...n_neighbors=11, weights=uniform;, score=0.351 total time=  14.3s
# [CV 4/5] END ...n_neighbors=11, weights=uniform;, score=0.346 total time=  13.9s
# [CV 5/5] END ...n_neighbors=11, weights=uniform;, score=0.353 total time=  14.1s
# [CV 1/5] END ..n_neighbors=11, weights=distance;, score=0.361 total time=  14.3s
# [CV 2/5] END ..n_neighbors=11, weights=distance;, score=0.365 total time=  14.1s
# [CV 3/5] END ..n_neighbors=11, weights=distance;, score=0.365 total time=  14.1s
# [CV 4/5] END ..n_neighbors=11, weights=distance;, score=0.358 total time=  13.8s
# [CV 5/5] END ..n_neighbors=11, weights=distance;, score=0.369 total time=  13.6s
# [CV 1/5] END ...n_neighbors=12, weights=uniform;, score=0.350 total time=  14.8s
# [CV 2/5] END ...n_neighbors=12, weights=uniform;, score=0.357 total time=  13.9s
# [CV 3/5] END ...n_neighbors=12, weights=uniform;, score=0.351 total time=  14.5s
# [CV 4/5] END ...n_neighbors=12, weights=uniform;, score=0.348 total time=  14.2s
# [CV 5/5] END ...n_neighbors=12, weights=uniform;, score=0.355 total time=  14.0s
# [CV 1/5] END ..n_neighbors=12, weights=distance;, score=0.353 total time=  14.3s
# [CV 2/5] END ..n_neighbors=12, weights=distance;, score=0.367 total time=  13.9s
# [CV 3/5] END ..n_neighbors=12, weights=distance;, score=0.365 total time=  14.0s
# [CV 4/5] END ..n_neighbors=12, weights=distance;, score=0.359 total time=  13.5s
# [CV 5/5] END ..n_neighbors=12, weights=distance;, score=0.367 total time=  14.0s
# [CV 1/5] END ...n_neighbors=13, weights=uniform;, score=0.346 total time=  14.6s
# [CV 2/5] END ...n_neighbors=13, weights=uniform;, score=0.354 total time=  14.1s
# [CV 3/5] END ...n_neighbors=13, weights=uniform;, score=0.351 total time=  14.2s
# [CV 4/5] END ...n_neighbors=13, weights=uniform;, score=0.346 total time=  13.7s
# [CV 5/5] END ...n_neighbors=13, weights=uniform;, score=0.358 total time=  13.9s
# [CV 1/5] END ..n_neighbors=13, weights=distance;, score=0.356 total time=  14.6s
# [CV 2/5] END ..n_neighbors=13, weights=distance;, score=0.366 total time=  13.8s
# [CV 3/5] END ..n_neighbors=13, weights=distance;, score=0.363 total time=  13.9s
# [CV 4/5] END ..n_neighbors=13, weights=distance;, score=0.357 total time=  13.7s
# [CV 5/5] END ..n_neighbors=13, weights=distance;, score=0.369 total time=  13.9s
# [CV 1/5] END ...n_neighbors=14, weights=uniform;, score=0.349 total time=  14.7s
# [CV 2/5] END ...n_neighbors=14, weights=uniform;, score=0.355 total time=  14.0s
# [CV 3/5] END ...n_neighbors=14, weights=uniform;, score=0.352 total time=  14.2s
# [CV 4/5] END ...n_neighbors=14, weights=uniform;, score=0.345 total time=  13.7s
# [CV 5/5] END ...n_neighbors=14, weights=uniform;, score=0.357 total time=  14.0s
# [CV 1/5] END ..n_neighbors=14, weights=distance;, score=0.354 total time=  14.6s
# [CV 2/5] END ..n_neighbors=14, weights=distance;, score=0.366 total time=  14.1s
# [CV 3/5] END ..n_neighbors=14, weights=distance;, score=0.363 total time=  14.1s
# [CV 4/5] END ..n_neighbors=14, weights=distance;, score=0.356 total time=  13.7s
# [CV 5/5] END ..n_neighbors=14, weights=distance;, score=0.371 total time=  14.2s
# [CV 1/5] END ...n_neighbors=15, weights=uniform;, score=0.351 total time=  14.5s
# [CV 2/5] END ...n_neighbors=15, weights=uniform;, score=0.359 total time=  14.3s
# [CV 3/5] END ...n_neighbors=15, weights=uniform;, score=0.354 total time=  14.1s
# [CV 4/5] END ...n_neighbors=15, weights=uniform;, score=0.342 total time=  13.9s
# [CV 5/5] END ...n_neighbors=15, weights=uniform;, score=0.357 total time=  14.2s
# [CV 1/5] END ..n_neighbors=15, weights=distance;, score=0.357 total time=  14.7s
# [CV 2/5] END ..n_neighbors=15, weights=distance;, score=0.369 total time=  14.3s
# [CV 3/5] END ..n_neighbors=15, weights=distance;, score=0.363 total time=  14.2s
# [CV 4/5] END ..n_neighbors=15, weights=distance;, score=0.354 total time=  13.7s
# [CV 5/5] END ..n_neighbors=15, weights=distance;, score=0.370 total time=  13.8s
# [CV 1/5] END ...n_neighbors=16, weights=uniform;, score=0.350 total time=  14.7s
# [CV 2/5] END ...n_neighbors=16, weights=uniform;, score=0.356 total time=  14.2s
# [CV 3/5] END ...n_neighbors=16, weights=uniform;, score=0.354 total time=  14.3s
# [CV 4/5] END ...n_neighbors=16, weights=uniform;, score=0.345 total time=  13.9s
# [CV 5/5] END ...n_neighbors=16, weights=uniform;, score=0.356 total time=  13.7s
# [CV 1/5] END ..n_neighbors=16, weights=distance;, score=0.356 total time=  14.6s
# [CV 2/5] END ..n_neighbors=16, weights=distance;, score=0.367 total time=  13.8s
# [CV 3/5] END ..n_neighbors=16, weights=distance;, score=0.362 total time=  14.0s
# [CV 4/5] END ..n_neighbors=16, weights=distance;, score=0.354 total time=  13.5s
# [CV 5/5] END ..n_neighbors=16, weights=distance;, score=0.368 total time=  13.8s
# [CV 1/5] END ...n_neighbors=17, weights=uniform;, score=0.348 total time=  14.5s
# [CV 2/5] END ...n_neighbors=17, weights=uniform;, score=0.357 total time=  14.0s
# [CV 3/5] END ...n_neighbors=17, weights=uniform;, score=0.353 total time=  14.3s
# [CV 4/5] END ...n_neighbors=17, weights=uniform;, score=0.345 total time=  13.9s
# [CV 5/5] END ...n_neighbors=17, weights=uniform;, score=0.354 total time=  13.9s
# [CV 1/5] END ..n_neighbors=17, weights=distance;, score=0.357 total time=  14.7s
# [CV 2/5] END ..n_neighbors=17, weights=distance;, score=0.366 total time=  14.2s
# [CV 3/5] END ..n_neighbors=17, weights=distance;, score=0.364 total time=  14.0s
# [CV 4/5] END ..n_neighbors=17, weights=distance;, score=0.352 total time=  13.7s
# [CV 5/5] END ..n_neighbors=17, weights=distance;, score=0.368 total time=  13.6s
# [CV 1/5] END ...n_neighbors=18, weights=uniform;, score=0.347 total time=  14.6s
# [CV 2/5] END ...n_neighbors=18, weights=uniform;, score=0.358 total time=  14.2s
# [CV 3/5] END ...n_neighbors=18, weights=uniform;, score=0.354 total time=  14.1s
# [CV 4/5] END ...n_neighbors=18, weights=uniform;, score=0.343 total time=  13.8s
# [CV 5/5] END ...n_neighbors=18, weights=uniform;, score=0.357 total time=  13.9s
# [CV 1/5] END ..n_neighbors=18, weights=distance;, score=0.356 total time=  14.2s
# [CV 2/5] END ..n_neighbors=18, weights=distance;, score=0.367 total time=  14.0s
# [CV 3/5] END ..n_neighbors=18, weights=distance;, score=0.362 total time=  14.0s
# [CV 4/5] END ..n_neighbors=18, weights=distance;, score=0.352 total time=  13.6s
# [CV 5/5] END ..n_neighbors=18, weights=distance;, score=0.369 total time=  13.8s
# [CV 1/5] END ...n_neighbors=19, weights=uniform;, score=0.348 total time=  14.5s
# [CV 2/5] END ...n_neighbors=19, weights=uniform;, score=0.360 total time=  13.9s
# [CV 3/5] END ...n_neighbors=19, weights=uniform;, score=0.351 total time=  14.0s
# [CV 4/5] END ...n_neighbors=19, weights=uniform;, score=0.344 total time=  13.9s
# [CV 5/5] END ...n_neighbors=19, weights=uniform;, score=0.357 total time=  14.0s
# [CV 1/5] END ..n_neighbors=19, weights=distance;, score=0.357 total time=  14.3s
# [CV 2/5] END ..n_neighbors=19, weights=distance;, score=0.367 total time=  13.9s
# [CV 3/5] END ..n_neighbors=19, weights=distance;, score=0.362 total time=  14.1s
# [CV 4/5] END ..n_neighbors=19, weights=distance;, score=0.352 total time=  13.7s
# [CV 5/5] END ..n_neighbors=19, weights=distance;, score=0.369 total time=  14.7s
# [CV 1/5] END ...n_neighbors=20, weights=uniform;, score=0.349 total time=  15.1s
# [CV 2/5] END ...n_neighbors=20, weights=uniform;, score=0.360 total time=  14.3s
# [CV 3/5] END ...n_neighbors=20, weights=uniform;, score=0.350 total time=  14.5s
# [CV 4/5] END ...n_neighbors=20, weights=uniform;, score=0.345 total time=  14.2s
# [CV 5/5] END ...n_neighbors=20, weights=uniform;, score=0.358 total time=  14.0s
# [CV 1/5] END ..n_neighbors=20, weights=distance;, score=0.356 total time=  14.3s
# [CV 2/5] END ..n_neighbors=20, weights=distance;, score=0.369 total time=  14.1s
# [CV 3/5] END ..n_neighbors=20, weights=distance;, score=0.361 total time=  14.2s
# [CV 4/5] END ..n_neighbors=20, weights=distance;, score=0.351 total time=  16.6s
# [CV 5/5] END ..n_neighbors=20, weights=distance;, score=0.369 total time=  14.1s
# [CV 1/5] END ...n_neighbors=21, weights=uniform;, score=0.346 total time=  15.1s
# [CV 2/5] END ...n_neighbors=21, weights=uniform;, score=0.360 total time=  14.3s
# [CV 3/5] END ...n_neighbors=21, weights=uniform;, score=0.351 total time=  14.2s
# [CV 4/5] END ...n_neighbors=21, weights=uniform;, score=0.344 total time=  14.1s
# [CV 5/5] END ...n_neighbors=21, weights=uniform;, score=0.358 total time=  14.1s
# [CV 1/5] END ..n_neighbors=21, weights=distance;, score=0.354 total time=  14.7s
# [CV 2/5] END ..n_neighbors=21, weights=distance;, score=0.368 total time=  14.1s
# [CV 3/5] END ..n_neighbors=21, weights=distance;, score=0.359 total time=  13.9s
# [CV 4/5] END ..n_neighbors=21, weights=distance;, score=0.352 total time=  14.9s
# [CV 5/5] END ..n_neighbors=21, weights=distance;, score=0.369 total time=  15.2s
# [CV 1/5] END ...n_neighbors=22, weights=uniform;, score=0.347 total time=  15.2s
# [CV 2/5] END ...n_neighbors=22, weights=uniform;, score=0.360 total time=  14.4s
# [CV 3/5] END ...n_neighbors=22, weights=uniform;, score=0.350 total time=  14.0s
# [CV 4/5] END ...n_neighbors=22, weights=uniform;, score=0.346 total time=  14.0s
# [CV 5/5] END ...n_neighbors=22, weights=uniform;, score=0.357 total time=  14.2s
# [CV 1/5] END ..n_neighbors=22, weights=distance;, score=0.355 total time=  14.4s
# [CV 2/5] END ..n_neighbors=22, weights=distance;, score=0.368 total time=  13.8s
# [CV 3/5] END ..n_neighbors=22, weights=distance;, score=0.357 total time=  13.9s
# [CV 4/5] END ..n_neighbors=22, weights=distance;, score=0.353 total time=  14.0s
# [CV 5/5] END ..n_neighbors=22, weights=distance;, score=0.367 total time=  13.8s
# [CV 1/5] END ...n_neighbors=23, weights=uniform;, score=0.347 total time=  14.6s
# [CV 2/5] END ...n_neighbors=23, weights=uniform;, score=0.358 total time=  14.2s
# [CV 3/5] END ...n_neighbors=23, weights=uniform;, score=0.351 total time=  14.0s
# [CV 4/5] END ...n_neighbors=23, weights=uniform;, score=0.344 total time=  14.7s
# [CV 5/5] END ...n_neighbors=23, weights=uniform;, score=0.357 total time=  14.5s
# [CV 1/5] END ..n_neighbors=23, weights=distance;, score=0.353 total time=  14.4s
# [CV 2/5] END ..n_neighbors=23, weights=distance;, score=0.367 total time=  14.9s
# [CV 3/5] END ..n_neighbors=23, weights=distance;, score=0.360 total time=  14.9s
# [CV 4/5] END ..n_neighbors=23, weights=distance;, score=0.351 total time=  15.2s
# [CV 5/5] END ..n_neighbors=23, weights=distance;, score=0.368 total time=  15.0s
# [CV 1/5] END ...n_neighbors=24, weights=uniform;, score=0.348 total time=  16.1s
# [CV 2/5] END ...n_neighbors=24, weights=uniform;, score=0.360 total time=  15.3s
# [CV 3/5] END ...n_neighbors=24, weights=uniform;, score=0.350 total time=  15.2s
# [CV 4/5] END ...n_neighbors=24, weights=uniform;, score=0.344 total time=  15.5s
# [CV 5/5] END ...n_neighbors=24, weights=uniform;, score=0.360 total time=  14.7s
# [CV 1/5] END ..n_neighbors=24, weights=distance;, score=0.353 total time=  15.6s
# [CV 2/5] END ..n_neighbors=24, weights=distance;, score=0.369 total time=  15.6s
# [CV 3/5] END ..n_neighbors=24, weights=distance;, score=0.359 total time=  16.8s
# [CV 4/5] END ..n_neighbors=24, weights=distance;, score=0.350 total time=  13.5s
# [CV 5/5] END ..n_neighbors=24, weights=distance;, score=0.368 total time=  13.8s
# 0.3640708868501688

# %%
print("Model optimal parameters".upper())
print("n_neighbors:", model_bw.get_params()["n_neighbors"])
print("weights:", model_bw.get_params()["weights"])
# Out:
# MODEL OPTIMAL PARAMETERS
# n_neighbors: 10
# weights: distance

# %% [markdown]
# ## Test model

# %%
predictions_bw = model_bw.predict(X_test_bw_pca)

accuracy_bw = accuracy_score(labels_test_bw, predictions_bw)
precision_bw = precision_score(labels_test_bw, predictions_bw, average="macro")
recall_bw = recall_score(labels_test_bw, predictions_bw, average="macro")
f1_macro_bw = f1_score(labels_test_bw, predictions_bw, average="macro")
f1_glob_bw = (2 * precision_bw * recall_bw) / (precision_bw + recall_bw)

print("Accuracy score: {:.4f}%\nPrecision macro: {:.4f}%\nRecall macro: {:.4f}%".format(accuracy_bw*100,precision_bw*100,recall_bw*100))
print("F1 macro: {:.4f}%\nF1 global: {:.4f}".format(f1_macro_bw*100, f1_glob_bw*100))
# Out:
# Accuracy score: 33.2300%
# Precision macro: 42.7422%
# Recall macro: 33.2300%
# F1 macro: 32.4220%
# F1 global: 37.3906

# %%
cm = confusion_matrix(labels_test_bw, predictions_bw, labels=model_bw.classes_)
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=model_bw.classes_)
disp.plot()
plt.plot()
# Out:
# []

# %% [markdown]
# ## Save model

# %%
if SAVE_MODELS:
    model_file_name_bw = "knn_bw_pca.pkl"
    pickle.dump(model_bw, open(model_file_name_bw, "wb"))
