# %%
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import pickle
import warnings

from sklearn.utils import shuffle
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, f1_score, precision_score, recall_score, confusion_matrix, ConfusionMatrixDisplay
from sklearn.model_selection import GridSearchCV, KFold
from sklearn.decomposition import PCA


from skimage.io import imread, imshow, show, imshow_collection
from skimage.transform import resize, rescale, rotate

warnings.filterwarnings('ignore')

# %% [markdown]
# # Load Data

# %%
data_train_1 = pickle.load(open("data/data_train_flatten_batch_1.pkl", "rb"))
data_train_2 = pickle.load(open("data/data_train_flatten_batch_2.pkl", "rb"))
labels_train_1 = pickle.load(open("data/labels_train_batch_1.pkl", "rb"))
labels_train_2 = pickle.load(open("data/labels_train_batch_2.pkl", "rb"))

data_train = np.concatenate((data_train_1, data_train_2))
labels_train = np.concatenate((labels_train_1, labels_train_2))

data_test = pickle.load(open("data/data_test_flatten.pkl", "rb"))
labels_test = pickle.load(open("data/labels_test.pkl", "rb"))

# Shuffle train set
data_train, labels_train = shuffle(data_train, labels_train, random_state=25)

# %% [markdown]
# # Scale Data

# %%
scaler = StandardScaler()

X_train_std = scaler.fit_transform(data_train)
X_test_std = scaler.transform(data_test)

# %% [markdown]
# # PCA
# We will use a 95% PCA

# %%
print("original number of features:", X_train_std.shape[1])
pca = PCA(0.95)
pca.fit(X_train_std)
print("Number of pricipal components:", pca.n_components_)

X_train_pca = pca.transform(X_train_std)
X_test_pca = pca.transform(X_test_std)
# Out:
# original number of features: 3072
# Number of pricipal components: 221

# %% [markdown]
# # Train Model

# %%
m = KNeighborsClassifier(n_jobs=4)

parameters = [{
    "n_neighbors": range(3, 25),
    "weights": ["uniform", "distance"]
}]

grid_search = GridSearchCV(m, parameters, verbose=3, scoring="f1_macro")
grid_search.fit(X_train_pca, labels_train)
model = grid_search.best_estimator_
# Out:
# Fitting 5 folds for each of 44 candidates, totalling 220 fits
# [CV 1/5] END ....n_neighbors=3, weights=uniform;, score=0.336 total time=  11.7s
# [CV 2/5] END ....n_neighbors=3, weights=uniform;, score=0.338 total time=  11.7s
# [CV 3/5] END ....n_neighbors=3, weights=uniform;, score=0.342 total time=  11.7s
# [CV 4/5] END ....n_neighbors=3, weights=uniform;, score=0.324 total time=  12.0s
# [CV 5/5] END ....n_neighbors=3, weights=uniform;, score=0.344 total time=  12.7s
# [CV 1/5] END ...n_neighbors=3, weights=distance;, score=0.353 total time=  11.6s
# [CV 2/5] END ...n_neighbors=3, weights=distance;, score=0.357 total time=  11.7s
# [CV 3/5] END ...n_neighbors=3, weights=distance;, score=0.371 total time=  11.7s
# [CV 4/5] END ...n_neighbors=3, weights=distance;, score=0.351 total time=  11.6s
# [CV 5/5] END ...n_neighbors=3, weights=distance;, score=0.376 total time=  11.7s
# [CV 1/5] END ....n_neighbors=4, weights=uniform;, score=0.338 total time=  13.2s
# [CV 2/5] END ....n_neighbors=4, weights=uniform;, score=0.344 total time=  12.9s
# [CV 3/5] END ....n_neighbors=4, weights=uniform;, score=0.349 total time=  12.7s
# [CV 4/5] END ....n_neighbors=4, weights=uniform;, score=0.329 total time=  12.6s
# [CV 5/5] END ....n_neighbors=4, weights=uniform;, score=0.348 total time=  12.7s
# [CV 1/5] END ...n_neighbors=4, weights=distance;, score=0.360 total time=  12.9s
# [CV 2/5] END ...n_neighbors=4, weights=distance;, score=0.359 total time=  12.4s
# [CV 1/5] END ..n_neighbors=15, weights=distance;, score=0.338 total time=  17.9s
# [CV 2/5] END ..n_neighbors=15, weights=distance;, score=0.355 total time=  15.7s
# [CV 3/5] END ..n_neighbors=15, weights=distance;, score=0.351 total time=  17.7s
# [CV 4/5] END ..n_neighbors=15, weights=distance;, score=0.339 total time=  16.1s
# [CV 5/5] END ..n_neighbors=15, weights=distance;, score=0.355 total time=  17.0s
# [CV 1/5] END ...n_neighbors=16, weights=uniform;, score=0.327 total time=  18.8s
# [CV 2/5] END ...n_neighbors=16, weights=uniform;, score=0.343 total time=  18.2s
# [CV 3/5] END ...n_neighbors=16, weights=uniform;, score=0.339 total time=  16.3s
# [CV 4/5] END ...n_neighbors=16, weights=uniform;, score=0.322 total time=  15.9s
# [CV 5/5] END ...n_neighbors=16, weights=uniform;, score=0.345 total time=  16.3s
# [CV 1/5] END ..n_neighbors=16, weights=distance;, score=0.336 total time=  19.0s
# [CV 2/5] END ..n_neighbors=16, weights=distance;, score=0.354 total time=  18.5s
# [CV 3/5] END ..n_neighbors=16, weights=distance;, score=0.349 total time=  15.8s
# [CV 4/5] END ..n_neighbors=16, weights=distance;, score=0.338 total time=  15.8s
# [CV 5/5] END ..n_neighbors=16, weights=distance;, score=0.356 total time=  16.7s
# [CV 1/5] END ...n_neighbors=17, weights=uniform;, score=0.325 total time=  20.8s
# [CV 2/5] END ...n_neighbors=17, weights=uniform;, score=0.341 total time=  17.3s
# [CV 3/5] END ...n_neighbors=17, weights=uniform;, score=0.341 total time=  16.3s
# [CV 4/5] END ...n_neighbors=17, weights=uniform;, score=0.321 total time=  15.9s
# [CV 5/5] END ...n_neighbors=17, weights=uniform;, score=0.343 total time=  16.7s
# [CV 1/5] END ..n_neighbors=17, weights=distance;, score=0.333 total time=  19.8s
# [CV 2/5] END ..n_neighbors=17, weights=distance;, score=0.351 total time=  16.4s
# [CV 3/5] END ..n_neighbors=17, weights=distance;, score=0.351 total time=  16.8s
# [CV 4/5] END ..n_neighbors=17, weights=distance;, score=0.332 total time=  15.3s
# [CV 5/5] END ..n_neighbors=17, weights=distance;, score=0.352 total time=  15.3s
# [CV 1/5] END ...n_neighbors=18, weights=uniform;, score=0.322 total time=  19.6s
# [CV 2/5] END ...n_neighbors=18, weights=uniform;, score=0.341 total time=  20.2s
# [CV 3/5] END ...n_neighbors=18, weights=uniform;, score=0.338 total time=  18.0s
# [CV 4/5] END ...n_neighbors=18, weights=uniform;, score=0.322 total time=  18.0s
# [CV 5/5] END ...n_neighbors=18, weights=uniform;, score=0.341 total time=  16.1s
# [CV 1/5] END ..n_neighbors=18, weights=distance;, score=0.331 total time=  17.4s
# [CV 2/5] END ..n_neighbors=18, weights=distance;, score=0.350 total time=  16.4s
# [CV 3/5] END ..n_neighbors=18, weights=distance;, score=0.349 total time=  17.7s
# [CV 4/5] END ..n_neighbors=18, weights=distance;, score=0.333 total time=  16.9s
# [CV 5/5] END ..n_neighbors=18, weights=distance;, score=0.350 total time=  15.8s
# [CV 1/5] END ...n_neighbors=19, weights=uniform;, score=0.318 total time=  17.9s
# [CV 3/5] END ..n_neighbors=22, weights=distance;, score=0.345 total time=  17.3s
# [CV 4/5] END ..n_neighbors=22, weights=distance;, score=0.327 total time=  15.2s
# [CV 5/5] END ..n_neighbors=22, weights=distance;, score=0.346 total time=  16.2s
# [CV 1/5] END ...n_neighbors=23, weights=uniform;, score=0.318 total time=  16.9s
# [CV 2/5] END ...n_neighbors=23, weights=uniform;, score=0.335 total time=  17.5s
# [CV 3/5] END ...n_neighbors=23, weights=uniform;, score=0.333 total time=  15.9s
# [CV 4/5] END ...n_neighbors=23, weights=uniform;, score=0.317 total time=  16.1s
# [CV 5/5] END ...n_neighbors=23, weights=uniform;, score=0.332 total time=  17.1s
# [CV 1/5] END ..n_neighbors=23, weights=distance;, score=0.330 total time=  16.8s
# [CV 2/5] END ..n_neighbors=23, weights=distance;, score=0.344 total time=  18.3s
# [CV 3/5] END ..n_neighbors=23, weights=distance;, score=0.345 total time=  17.9s
# [CV 4/5] END ..n_neighbors=23, weights=distance;, score=0.324 total time=  15.5s
# [CV 5/5] END ..n_neighbors=23, weights=distance;, score=0.344 total time=  15.7s
# [CV 1/5] END ...n_neighbors=24, weights=uniform;, score=0.320 total time=  19.2s
# [CV 2/5] END ...n_neighbors=24, weights=uniform;, score=0.336 total time=  17.6s
# [CV 3/5] END ...n_neighbors=24, weights=uniform;, score=0.333 total time=  19.3s
# [CV 4/5] END ...n_neighbors=24, weights=uniform;, score=0.319 total time=  15.3s
# [CV 5/5] END ...n_neighbors=24, weights=uniform;, score=0.332 total time=  16.6s
# [CV 1/5] END ..n_neighbors=24, weights=distance;, score=0.332 total time=  18.3s
# [CV 2/5] END ..n_neighbors=24, weights=distance;, score=0.342 total time=  17.5s
# [CV 3/5] END ..n_neighbors=24, weights=distance;, score=0.343 total time=  16.4s
# [CV 4/5] END ..n_neighbors=24, weights=distance;, score=0.328 total time=  15.6s
# [CV 5/5] END ..n_neighbors=24, weights=distance;, score=0.343 total time=  15.8s

# %%
print("Model optimal parameters".upper())
print("n_neighbors:", model.get_params()["n_neighbors"])
print("weights:", model.get_params()["weights"])
# Out:
# MODEL OPTIMAL PARAMETERS
# n_neighbors: 6
# weights: distance

# %% [markdown]
# # Test Model

# %%
predictions = model.predict(X_test_pca)

accuracy = accuracy_score(labels_test, predictions)
precision = precision_score(labels_test, predictions, average="macro")
recall = recall_score(labels_test, predictions, average="macro")
f1_macro = f1_score(labels_test, predictions, average="macro")

print("Accuracy score: {:.4f}%\nPrecision macro: {:.4f}%\nRecall macro: {:.4f}%\nF1 macro: {:.4f}%".format(accuracy*100, precision*100, recall*100, f1_macro*100))
# Out:
# Accuracy score: 38.1100%
# Precision macro: 45.8007%
# Recall macro: 38.1100%
# F1 macro: 37.4606%

# %%
cm = confusion_matrix(labels_test, predictions, labels=model.classes_)
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=model.classes_)
disp.plot()
plt.show()

# %% [markdown]
# # Save Model

# %%
model_file_name = "KNN_32x32_PCA.pkl"
pickle.dump(model, open(model_file_name, "wb"))

# %% [markdown]
# # Black And White

# %% [markdown]
# ## Load data

# %%
train_batches = []
labels_batches = []

for i in [1, 2, 3, 4, 5]:
    data_filepath = "data/data_train_bw_flatten_batch_" + str(i) + ".pkl"
    labels_filepath = "data/labels_train_bw_batch_" + str(i) + ".pkl"
    train_batches.append(pickle.load(open(data_filepath, "rb")))
    labels_batches.append(pickle.load(open(labels_filepath, "rb")))
    
data_train_bw = np.concatenate(train_batches)
labels_train_bw = np.concatenate(labels_batches)

data_test_bw = pickle.load(open("data/data_test_bw_flatten.pkl", "rb"))
labels_test_bw = pickle.load(open("data/labels_test_bw.pkl", "rb"))

# Shuffle train set
data_train_bw, labels_train_bw = shuffle(data_train_bw, labels_train_bw, random_state=25)

# %% [markdown]
# ## Scale data

# %%
scaler = StandardScaler()

X_train_std_bw = scaler.fit_transform(data_train_bw)
X_test_std_bw = scaler.transform(data_test_bw)

# %% [markdown]
# ## PCA
# We will use a 95% PCA

# %%
del pca
print("original number of features:", X_train_std_bw.shape[1])
pca = PCA(0.95)
pca.fit(X_train_std_bw)
print("Number of pricipal components:", pca.n_components_)

X_train_bw_pca = pca.transform(X_train_std_bw)
X_test_bw_pca = pca.transform(X_test_std_bw)
# Out:
# original number of features: 1024
# Number of pricipal components: 163

# %% [markdown]
# ## Train model

# %%
m = KNeighborsClassifier(n_jobs=4)

parameters = [{
    "n_neighbors": range(3, 25),
    "weights": ["uniform", "distance"]
}]

grid_search = GridSearchCV(m, parameters, verbose=3, scoring="f1_macro")
grid_search.fit(X_train_bw_pca, labels_train_bw)
model_bw = grid_search.best_estimator_
# Out:
# Fitting 5 folds for each of 44 candidates, totalling 220 fits
# [CV 1/5] END ....n_neighbors=3, weights=uniform;, score=0.285 total time=  15.7s
# [CV 2/5] END ....n_neighbors=3, weights=uniform;, score=0.287 total time=  14.7s
# [CV 3/5] END ....n_neighbors=3, weights=uniform;, score=0.299 total time=  15.0s
# [CV 4/5] END ....n_neighbors=3, weights=uniform;, score=0.281 total time=  14.3s
# [CV 5/5] END ....n_neighbors=3, weights=uniform;, score=0.302 total time=  16.8s
# [CV 1/5] END ...n_neighbors=3, weights=distance;, score=0.317 total time=  14.3s
# [CV 2/5] END ...n_neighbors=3, weights=distance;, score=0.317 total time=  15.3s
# [CV 3/5] END ...n_neighbors=3, weights=distance;, score=0.327 total time=  14.0s
# [CV 4/5] END ...n_neighbors=3, weights=distance;, score=0.308 total time=  14.8s
# [CV 5/5] END ...n_neighbors=3, weights=distance;, score=0.330 total time=  14.8s
# [CV 1/5] END ....n_neighbors=4, weights=uniform;, score=0.290 total time=  16.9s
# [CV 2/5] END ....n_neighbors=4, weights=uniform;, score=0.297 total time=  16.2s
# [CV 3/5] END ....n_neighbors=4, weights=uniform;, score=0.304 total time=  18.7s
# [CV 4/5] END ....n_neighbors=4, weights=uniform;, score=0.286 total time=  15.4s
# [CV 5/5] END ....n_neighbors=4, weights=uniform;, score=0.308 total time=  16.1s
# [CV 1/5] END ...n_neighbors=4, weights=distance;, score=0.315 total time=  18.6s
# [CV 2/5] END ...n_neighbors=4, weights=distance;, score=0.319 total time=  16.2s
# [CV 3/5] END ...n_neighbors=4, weights=distance;, score=0.327 total time=  18.3s
# [CV 2/5] END ..n_neighbors=15, weights=distance;, score=0.312 total time=  15.8s
# [CV 3/5] END ..n_neighbors=15, weights=distance;, score=0.309 total time=  16.4s
# [CV 4/5] END ..n_neighbors=15, weights=distance;, score=0.298 total time=  14.3s
# [CV 5/5] END ..n_neighbors=15, weights=distance;, score=0.316 total time=  15.0s
# [CV 1/5] END ...n_neighbors=16, weights=uniform;, score=0.289 total time=  15.7s
# [CV 2/5] END ...n_neighbors=16, weights=uniform;, score=0.297 total time=  16.3s
# [CV 3/5] END ...n_neighbors=16, weights=uniform;, score=0.298 total time=  16.0s
# [CV 4/5] END ...n_neighbors=16, weights=uniform;, score=0.287 total time=  14.1s
# [CV 5/5] END ...n_neighbors=16, weights=uniform;, score=0.299 total time=  14.9s
# [CV 1/5] END ..n_neighbors=16, weights=distance;, score=0.296 total time=  16.6s
# [CV 2/5] END ..n_neighbors=16, weights=distance;, score=0.309 total time=  16.2s
# [CV 3/5] END ..n_neighbors=16, weights=distance;, score=0.307 total time=  16.2s
# [CV 4/5] END ..n_neighbors=16, weights=distance;, score=0.298 total time=  15.4s
# [CV 5/5] END ..n_neighbors=16, weights=distance;, score=0.313 total time=  16.1s
# [CV 1/5] END ...n_neighbors=17, weights=uniform;, score=0.285 total time=  15.3s
# [CV 2/5] END ...n_neighbors=17, weights=uniform;, score=0.297 total time=  15.5s
# [CV 3/5] END ...n_neighbors=17, weights=uniform;, score=0.296 total time=  17.4s
# [CV 4/5] END ...n_neighbors=17, weights=uniform;, score=0.286 total time=  15.6s
# [CV 5/5] END ...n_neighbors=17, weights=uniform;, score=0.298 total time=  15.3s
# [CV 1/5] END ..n_neighbors=17, weights=distance;, score=0.296 total time=  15.5s
# [CV 2/5] END ..n_neighbors=17, weights=distance;, score=0.308 total time=  17.5s
# [CV 3/5] END ..n_neighbors=17, weights=distance;, score=0.308 total time=  14.7s
# [CV 4/5] END ..n_neighbors=17, weights=distance;, score=0.296 total time=  15.3s
# [CV 5/5] END ..n_neighbors=17, weights=distance;, score=0.313 total time=  15.3s
# [CV 1/5] END ...n_neighbors=18, weights=uniform;, score=0.284 total time=  15.9s
# [CV 2/5] END ...n_neighbors=18, weights=uniform;, score=0.297 total time=  16.1s
# [CV 3/5] END ...n_neighbors=18, weights=uniform;, score=0.297 total time=  15.9s
# [CV 4/5] END ...n_neighbors=18, weights=uniform;, score=0.284 total time=  14.8s
# [CV 5/5] END ...n_neighbors=18, weights=uniform;, score=0.300 total time=  15.3s
# [CV 1/5] END ..n_neighbors=18, weights=distance;, score=0.294 total time=  15.1s
# [CV 2/5] END ..n_neighbors=18, weights=distance;, score=0.307 total time=  15.1s
# [CV 3/5] END ..n_neighbors=18, weights=distance;, score=0.306 total time=  16.1s
# [CV 4/5] END ..n_neighbors=18, weights=distance;, score=0.295 total time=  14.6s
# [CV 5/5] END ..n_neighbors=18, weights=distance;, score=0.313 total time=  15.5s
# [CV 1/5] END ...n_neighbors=19, weights=uniform;, score=0.285 total time=  16.3s
# [CV 2/5] END ...n_neighbors=19, weights=uniform;, score=0.298 total time=  14.8s
# [CV 3/5] END ...n_neighbors=19, weights=uniform;, score=0.294 total time=  15.5s
# [CV 4/5] END ...n_neighbors=19, weights=uniform;, score=0.284 total time=  14.9s
# [CV 5/5] END ...n_neighbors=19, weights=uniform;, score=0.299 total time=  14.2s
# [CV 1/5] END ..n_neighbors=19, weights=distance;, score=0.293 total time=  17.0s
# [CV 2/5] END ..n_neighbors=19, weights=distance;, score=0.307 total time=  15.1s
# [CV 3/5] END ..n_neighbors=19, weights=distance;, score=0.305 total time=  16.9s
# [CV 4/5] END ..n_neighbors=19, weights=distance;, score=0.294 total time=  14.8s
# [CV 5/5] END ..n_neighbors=19, weights=distance;, score=0.312 total time=  14.8s
# [CV 1/5] END ...n_neighbors=20, weights=uniform;, score=0.284 total time=  17.0s
# [CV 2/5] END ...n_neighbors=20, weights=uniform;, score=0.298 total time=  14.8s
# [CV 3/5] END ...n_neighbors=20, weights=uniform;, score=0.292 total time=  16.7s
# [CV 4/5] END ...n_neighbors=20, weights=uniform;, score=0.285 total time=  15.1s
# [CV 5/5] END ...n_neighbors=20, weights=uniform;, score=0.300 total time=  14.4s
# [CV 1/5] END ..n_neighbors=20, weights=distance;, score=0.292 total time=  15.8s
# [CV 2/5] END ..n_neighbors=20, weights=distance;, score=0.307 total time=  15.5s
# [CV 3/5] END ..n_neighbors=20, weights=distance;, score=0.303 total time=  14.7s
# [CV 4/5] END ..n_neighbors=20, weights=distance;, score=0.292 total time=  16.6s
# [CV 5/5] END ..n_neighbors=20, weights=distance;, score=0.311 total time=  14.7s
# [CV 1/5] END ...n_neighbors=21, weights=uniform;, score=0.281 total time=  15.8s
# [CV 2/5] END ...n_neighbors=21, weights=uniform;, score=0.297 total time=  15.4s
# [CV 3/5] END ...n_neighbors=21, weights=uniform;, score=0.292 total time=  16.4s
# [CV 4/5] END ...n_neighbors=21, weights=uniform;, score=0.283 total time=  17.9s
# [CV 5/5] END ...n_neighbors=21, weights=uniform;, score=0.299 total time=  16.9s
# [CV 1/5] END ..n_neighbors=21, weights=distance;, score=0.289 total time=  16.7s
# [CV 2/5] END ..n_neighbors=21, weights=distance;, score=0.305 total time=  14.9s
# [CV 3/5] END ..n_neighbors=21, weights=distance;, score=0.300 total time=  17.6s
# [CV 4/5] END ..n_neighbors=21, weights=distance;, score=0.292 total time=  16.0s
# [CV 5/5] END ..n_neighbors=21, weights=distance;, score=0.310 total time=  15.4s
# [CV 1/5] END ...n_neighbors=22, weights=uniform;, score=0.280 total time=  18.3s
# [CV 2/5] END ...n_neighbors=22, weights=uniform;, score=0.296 total time=  17.0s
# [CV 3/5] END ...n_neighbors=22, weights=uniform;, score=0.290 total time=  17.4s
# [CV 4/5] END ...n_neighbors=22, weights=uniform;, score=0.284 total time=  16.8s
# [CV 5/5] END ...n_neighbors=22, weights=uniform;, score=0.298 total time=  16.1s
# [CV 1/5] END ..n_neighbors=22, weights=distance;, score=0.289 total time=  20.3s
# [CV 2/5] END ..n_neighbors=22, weights=distance;, score=0.305 total time=  16.7s
# [CV 3/5] END ..n_neighbors=22, weights=distance;, score=0.298 total time=  19.1s
# [CV 4/5] END ..n_neighbors=22, weights=distance;, score=0.293 total time=  21.4s
# [CV 5/5] END ..n_neighbors=22, weights=distance;, score=0.308 total time=  16.2s
# [CV 1/5] END ...n_neighbors=23, weights=uniform;, score=0.279 total time=  17.2s
# [CV 2/5] END ...n_neighbors=23, weights=uniform;, score=0.294 total time=  16.0s
# [CV 3/5] END ...n_neighbors=23, weights=uniform;, score=0.291 total time=  15.6s
# [CV 4/5] END ...n_neighbors=23, weights=uniform;, score=0.282 total time=  15.0s
# [CV 5/5] END ...n_neighbors=23, weights=uniform;, score=0.298 total time=  17.1s
# [CV 1/5] END ..n_neighbors=23, weights=distance;, score=0.286 total time=  16.9s
# [CV 2/5] END ..n_neighbors=23, weights=distance;, score=0.304 total time=  15.9s
# [CV 3/5] END ..n_neighbors=23, weights=distance;, score=0.300 total time=  16.6s
# [CV 4/5] END ..n_neighbors=23, weights=distance;, score=0.291 total time=  15.3s
# [CV 5/5] END ..n_neighbors=23, weights=distance;, score=0.309 total time=  15.7s
# [CV 1/5] END ...n_neighbors=24, weights=uniform;, score=0.278 total time=  16.6s
# [CV 2/5] END ...n_neighbors=24, weights=uniform;, score=0.294 total time=  15.6s
# [CV 3/5] END ...n_neighbors=24, weights=uniform;, score=0.290 total time=  15.2s
# [CV 4/5] END ...n_neighbors=24, weights=uniform;, score=0.281 total time=  16.9s
# [CV 5/5] END ...n_neighbors=24, weights=uniform;, score=0.299 total time=  16.6s
# [CV 1/5] END ..n_neighbors=24, weights=distance;, score=0.285 total time=  17.6s
# [CV 2/5] END ..n_neighbors=24, weights=distance;, score=0.304 total time=  16.2s
# [CV 3/5] END ..n_neighbors=24, weights=distance;, score=0.299 total time=  15.1s
# [CV 4/5] END ..n_neighbors=24, weights=distance;, score=0.288 total time=  14.9s
# [CV 5/5] END ..n_neighbors=24, weights=distance;, score=0.308 total time=  16.0s

# %%
print("Model optimal parameters".upper())
print("n_neighbors:", model_bw.get_params()["n_neighbors"])
print("weights:", model_bw.get_params()["weights"])
# Out:
# MODEL OPTIMAL PARAMETERS
# n_neighbors: 4
# weights: distance

# %% [markdown]
# ## Test model

# %%
predictions_bw = model_bw.predict(X_test_bw_pca)

accuracy_bw = accuracy_score(labels_test_bw, predictions_bw)
precision_bw = precision_score(labels_test_bw, predictions_bw, average="macro")
recall_bw = recall_score(labels_test_bw, predictions_bw, average="macro")
f1_macro_bw = f1_score(labels_test_bw, predictions_bw, average="macro")

print("Accuracy score: {:.4f}%\nPrecision macro: {:.4f}%\nRecall macro: {:.4f}%\nF1 macro: {:.4f}%".format(accuracy_bw*100, precision_bw*100, recall_bw*100, f1_macro_bw*100))
# Out:
# Accuracy score: 33.6800%
# Precision macro: 40.5151%
# Recall macro: 33.6800%
# F1 macro: 33.3548%

# %%
cm = confusion_matrix(labels_test_bw, predictions_bw, labels=model_bw.classes_)
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=model_bw.classes_)
disp.plot()
plt.plot()
# Out:
# []

# %% [markdown]
# ## Save model

# %%
model_file_name_bw = "KNN_32x32_bw_PCA.pkl"
pickle.dump(model_bw, open(model_file_name_bw, "wb"))
